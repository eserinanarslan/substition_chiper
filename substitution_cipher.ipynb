# %%
import collections, re

# %%
def get_ciphertext_letters_by_frequency(ciphertext):
    ciphertext_nopunc = re.sub(r"\W+", "", ciphertext)
    letter_freqs = collections.Counter(ciphertext_nopunc)
    return [i[0] for i in letter_freqs.most_common()]

# %%
def reconstruct_key(ciphertext_letters):
    letters_ordered_by_freq = ["E","T","A","O","I","N","S","R","H","D","L",
        "U","C","M","F","Y","W","G","P","B","V","K","X","Q","J","Z"]
    return zip(ciphertext_letters, letters_ordered_by_freq)

# %%
def get_manually_tweaked_key():
    return [
        ('r', 'E'), ('b', 'T'), ('m', 'A'),
        ('k', 'N'), ('j', 'O'), ('w', 'I'),
        ('i', 'S'), ('p', 'H'), ('u', 'R'),
        ('d', 'D'), ('h', 'L'), ('v', 'C'),
        ('x', 'F'), ('y', 'M'), ('n', 'U'),
        ('s', 'P'), ('t', 'Y'), ('l', 'B'),
        ('o', 'G'), ('q', 'K'), ('a', 'X'),
        ('c', 'W'), ('e', 'V'), ('g', 'Z'),
        ('f', 'Q')
    ]

# %%
def decipher(ciphertext, key):
    for x, y in key:
        ciphertext = ciphertext.replace(x, y)
    return ciphertext

# %%
def print_ciphertext(ciphertext):
    print("\n===========")
    print ("Ciphertext:")
    print ("===========")
    print (ciphertext)

# %%
def print_deciphered_plaintext(type, key, plaintext):
    header = "{} Statistical Key Reconstruction:".format(type)
    print ("=" * len(header), "\n", header, "\n", "=" * len(header))
    print ("\n", "Key:", "\n")
    sorted(key, key=lambda x:x[1])
    i = 0
    for x, y in key:
        print ("{} = {},".format(y, x),)
        i += 1
        if not i % 5: print
    print ("\n", plaintext)

# %%
with open("chiphertext.txt") as f:
    ciphertext = f.read()
    print_ciphertext(ciphertext)
    ciphertext_letters = get_ciphertext_letters_by_frequency(ciphertext)
    key = reconstruct_key(ciphertext_letters)
    print_deciphered_plaintext("Naive", key, decipher(ciphertext, key))
    key = get_manually_tweaked_key()
    print_deciphered_plaintext("Manually Tweaked", key, decipher(ciphertext, key))
# Out:
# ===========
# Ciphertext:
# ===========
# {\rtf1\ansi\ansicpg1252\cocoartf2511
# \cocoatextscaling0\cocoaplatform0{\fonttbl\f0\fmodern\fcharset0 Courier;}
# {\colortbl;\red255\green255\blue255;\red0\green0\blue0;\red255\green255\blue255;}
# {\*\expandedcolortbl;;\cssrgb\c0\c0\c0;\cssrgb\c100000\c100000\c100000;}
# \paperw11900\paperh16840\margl1440\margr1440\vieww10800\viewh8400\viewkind0
# \deftab720
# \pard\pardeftab720\sl400\partightenfactor0
#
# \f0\fs33\fsmilli16600 \cf2 \cb3 \expnd0\expndtw0\kerning0
# \outl0\strokewidth0 \strokec2 lrvmnir bpr sumvbwvr jx bpr lmiwv \cf0 \strokec0 \
# \cf2 \strokec2 yjeryrkbi jx qmbm wi bpr xjvni mkd ymibrut jx \cf0 \strokec0 \
# \cf2 \strokec2 irhx wi bpr riirkvr jx ymbinlmtmipw utn qmumbr dj w ipmhh but bj rhnvwdmbr bpr \cf0 \strokec0 \
# \cf2 \strokec2 yjeryrkbi jx bpr qmbm mvvjudwko bj yt wkbrusurbmbwjk lmird jk xjubt trmui jx \cf0 \strokec0 \
# \cf2 \strokec2 ibndt\cf0 \strokec0 \
# \cf2 \strokec2 wb wi kjb mk rmit bmiq bj rashmwk rmvp yjeryrkb \cf0 \strokec0 \
# \cf2 \strokec2 mkd wbi iwokwxwvmkvr mkd ijyr \cf0 \strokec0 \
# \cf2 \strokec2 ynib urymwk nkrashmwkrd bj ower m vjyshrbr rashmkmbwjk jkr cjnhd pmer bj lr \cf0 \strokec0 \
# \cf2 \strokec2 fnmhwxwrd  mkd  wkiswurd  bj  invp  mk  rabrkb  bpmb  pr  vjnhd  urmvp  bpr  ibmbr  jx \cf0 \strokec0 \
# \cf2 \strokec2 rkhwopbrkrd ywkd vmsmlhr jx urvjokwgwko ijnkdhrii ijnkd mkd ipmsrhrii ipmsr \cf0 \strokec0 \
# \cf2 \strokec2 w \cf0 \strokec0 \
# \cf2 \strokec2 dj kjb drry ytirhx bpr xwkmh mnbpjuwbt lnb yt rasruwrkvr cwbp qmbm pmi hrxb kj \cf0 \strokec0 \
# \cf2 \strokec2 djnlb bpmb bpr xjhhjcwko wi bpr sujsru msshwvmbwjk mkd wkbrusurbmbwjk w jxxru \cf0 \strokec0 \
# \cf2 \strokec2 yt bprjuwri wk bpr pjsr bpmb bpr riirkvr jx jqwkmcmk qmumbr cwhh urymwk wkbmvb\cf0 \strokec0 \
# }
# =====================================
#  Naive Statistical Key Reconstruction:
#  =====================================
#
#  Key:
#
#
#  {\ERMZ\KGHD\KGHDTFgZY5Y\TUTUKERMY5ZZ
# \TUTUKRSXRHTKQDGgI\TUTUKFQKRMUENI{\MUGRROQ\MI\MNUWSEG\MTBKEHSRI CUPEDSE;}
# {\TUQUEROQ;\ESWY55\gESSGY55\OQPSY55;\ESWI\gESSGI\OQPSI;\ESWY55\gESSGY55\OQPSY55;}
# {\*\SXFKGWSWTUQUEROQ;;\THHEgO\TI\TI\TI;\THHEgO\TZIIIII\TZIIIII\TZIIIII;}
# \FKFSELZZ9II\FKFSEBZ684I\NKEgQZ44I\NKEgEZ44I\VDSLLZI8II\VDSLB84II\VDSLADGWI
# \WSMRKO7YI
# \FKEW\FKEWSMRKO7YI\HQ4II\FKERDgBRSGMKTRUEI
#
# \MI\MH33\MHNDQQDZ66II \TMY \TO3 \SXFGWI\SXFGWRLI\ASEGDGgI
# \UPRQI\HREUASLDWRBI \HREUASTY QEVNGDE OFE HPNVOLVE CX OFE QNDLV \TMI \HREUASTI \
# \TMY \HREUASTY JCSEJEAOD CX qNON LD OFE XCVGD NAW JNDOEPR CX \TMI \HREUASTI \
# \TMY \HREUASTY DEBX LD OFE EDDEAVE CX JNODGQNRNDFL PRG qNPNOE WC L DFNBB OPR OC EBGVLWNOE OFE \TMI \HREUASTI \
# \TMY \HREUASTY JCSEJEAOD CX OFE qNON NVVCPWLAU OC JR LAOEPHPEONOLCA QNDEW CA XCPOR RENPD CX \TMI \HREUASTI \
# \TMY \HREUASTY DOGWR\TMI \HREUASTI \
# \TMY \HREUASTY LO LD ACO NA ENDR ONDq OC EKHBNLA ENVF JCSEJEAO \TMI \HREUASTI \
# \TMY \HREUASTY NAW LOD DLUALXLVNAVE NAW DCJE \TMI \HREUASTI \
# \TMY \HREUASTY JGDO PEJNLA GAEKHBNLAEW OC ULSE N VCJHBEOE EKHBNANOLCA CAE TCGBW FNSE OC QE \TMI \HREUASTI \
# \TMY \HREUASTY MGNBLXLEW  NAW  LADHLPEW  OC  DGVF  NA  EKOEAO  OFNO  FE  VCGBW  PENVF  OFE  DONOE  CX \TMI \HREUASTI \
# \TMY \HREUASTY EABLUFOEAEW JLAW VNHNQBE CX PEVCUALgLAU DCGAWBEDD DCGAW NAW DFNHEBEDD DFNHE \TMI \HREUASTI \
# \TMY \HREUASTY L \TMI \HREUASTI \
# \TMY \HREUASTY WC ACO WEEJ JRDEBX OFE XLANB NGOFCPLOR QGO JR EKHEPLEAVE TLOF qNON FND BEXO AC \TMI \HREUASTI \
# \TMY \HREUASTY WCGQO OFNO OFE XCBBCTLAU LD OFE HPCHEP NHHBLVNOLCA NAW LAOEPHPEONOLCA L CXXEP \TMI \HREUASTI \
# \TMY \HREUASTY JR OFECPLED LA OFE FCHE OFNO OFE EDDEAVE CX CqLANTNA qNPNOE TLBB PEJNLA LAONVO\TMI \HREUASTI \
# }
# ================================================
#  Manually Tweaked Statistical Key Reconstruction:
#  ================================================
#
#  Key:
#
# E = r,
# T = b,
# A = m,
# N = k,
# O = j,
# I = w,
# S = i,
# H = p,
# R = u,
# D = d,
# L = h,
# C = v,
# F = x,
# M = y,
# U = n,
# P = s,
# Y = t,
# B = l,
# G = o,
# K = q,
# X = a,
# W = c,
# V = e,
# Z = g,
# Q = f,
#
#  {\EYQ1\XUPS\XUPSWHZ1252\WGWGXEYQ2511
# \WGWGXYVFYPWXBSUZ0\WGWGXHBXYQGEA0{\QGUYYTB\Q0\QAGDVEU\QWLXEPVY0 CGRESVE;}
# {\WGBGEYTB;\EVD255\ZEVVU255\TBRV255;\EVD0\ZEVVU0\TBRV0;\EVD255\ZEVVU255\TBRV255;}
# {\*\VFHXUDVDWGBGEYTB;;\WPPEZT\W0\W0\W0;\WPPEZT\W100000\W100000\W100000;}
# \HXHVEI11900\HXHVEL16840\AXEZB1440\AXEZE1440\CSVII10800\CSVIL8400\CSVINSUD0
# \DVQYXT720
# \HXED\HXEDVQYXT720\PB400\HXEYSZLYVUQXWYGE0
#
# \Q0\QP33\QPASBBS16600 \WQ2 \WT3 \VFHUD0\VFHUDYI0\NVEUSUZ0
# \GRYB0\PYEGNVISDYL0 \PYEGNVW2 BECAUSE THE PRACTICE OF THE BASIC \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 MOVEMENTS OF KATA IS THE FOCUS AND MASTERY OF \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 SELF IS THE ESSENCE OF MATSUBAYASHI RYU KARATE DO I SHALL TRY TO ELUCIDATE THE \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 MOVEMENTS OF THE KATA ACCORDING TO MY INTERPRETATION BASED ON FORTY YEARS OF \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 STUDY\WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 IT IS NOT AN EASY TASK TO EXPLAIN EACH MOVEMENT \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 AND ITS SIGNIFICANCE AND SOME \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 MUST REMAIN UNEXPLAINED TO GIVE A COMPLETE EXPLANATION ONE WOULD HAVE TO BE \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 QUALIFIED  AND  INSPIRED  TO  SUCH  AN  EXTENT  THAT  HE  COULD  REACH  THE  STATE  OF \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 ENLIGHTENED MIND CAPABLE OF RECOGNIZING SOUNDLESS SOUND AND SHAPELESS SHAPE \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 I \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 DO NOT DEEM MYSELF THE FINAL AUTHORITY BUT MY EXPERIENCE WITH KATA HAS LEFT NO \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 DOUBT THAT THE FOLLOWING IS THE PROPER APPLICATION AND INTERPRETATION I OFFER \WQ0 \PYEGNVW0 \
# \WQ2 \PYEGNVW2 MY THEORIES IN THE HOPE THAT THE ESSENCE OF OKINAWAN KARATE WILL REMAIN INTACT\WQ0 \PYEGNVW0 \
# }
